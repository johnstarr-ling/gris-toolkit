# %% [markdown]
# # SAMPLE DATA PROCESSING PIPELINES
#
# Hi! Say you've collected some data on PC Ibex, transformed the raw data into a cleaner file (using `process_raw_data.R`), and now you're looking to analyze what you've got. But, GRIS experiments come with a lot of data, and it can be difficult to know where to start.
#
# This notebook will outline three sample data pipelines (two gradient templates, one categorical template; the type of analysis is demarcated in the header for each sample pipeline). Rather than having to write all of the data analysis code yourself, we've provided you some (optimized) functions in `utils.py` that will help us get what we need from our data.

# %%
import numpy as np
import pandas as pd 
import ast
from utils import *

# %% [markdown]
# ## SAMPLE PIPELINE 1 (GRADIENT):
# #### Semantic Proto-Roles data provided by Zander Lynch (zcl7@cornell.edu)
#
# Zander Lynch ran a GRIS experiment that studies how people process differences in semantic proto roles. *To avoid issues with generalization, we do not line up the experimental items (and their conditions) with the results files.* However, we do process the results file such that it can be easily aligned with the stimuli.
#
# Note that Zander's experiment uses an earlier version of GRIS where coordinates are 2D (x, y), as opposed to the most recent version of GRIS where coordinates are 4D (x_cat, y_cat, x, y). The functions provided in `utils.py` natively account for this flexibility.

# %%
# Read in the data
data = pd.read_csv('data/demo-1-cleaned.csv')

# %%
# See what the data look like
data.head()
# Out:
#    Results.reception.time MD5.hash.of.participant.s.IP.address  \
# 0              1742304662     abda418378729d84a1a46fe1f54043bc
# 1              1742304662     abda418378729d84a1a46fe1f54043bc
# 2              1742304662     abda418378729d84a1a46fe1f54043bc
# 3              1742304662     abda418378729d84a1a46fe1f54043bc
# 4              1742304662     abda418378729d84a1a46fe1f54043bc
#
#   Controller.name  Order.number.of.item  Inner.element.number        Label  \
# 0  PennController                     1                     0  Prolific-ID
# 1  PennController                     1                     0  Prolific-ID
# 2  PennController                     1                     0  Prolific-ID
# 3  PennController                     1                     0  Prolific-ID
# 4  PennController                     1                     0  Prolific-ID
#
#    Latin.Square.Group PennElementType PennElementName    Parameter  ...  \
# 0                 NaN  PennController               0      _Trial_  ...
# 1                 NaN  PennController               0     _Header_  ...
# 2                 NaN  PennController               0     _Header_  ...
# 3                 NaN             Var         subject        Final  ...
# 4                 NaN       TextInput    Pro-ID-input  EnterReturn  ...
#
#   Sentence4Cond  Sentence5  Sentence5Cond Sentence6 Sentence6Cond  Sentence7  \
# 0           NaN        NaN            NaN       NaN           NaN        NaN
# 1           NaN        NaN            NaN       NaN           NaN        NaN
# 2           NaN        NaN            NaN       NaN           NaN        NaN
# 3           NaN        NaN            NaN       NaN           NaN        NaN
# 4           NaN        NaN            NaN       NaN           NaN        NaN
#
#   Sentence7Cond Sentence8 Sentence8Cond Comments
# 0           NaN       NaN           NaN      NaN
# 1           NaN       NaN           NaN      NaN
# 2           NaN       NaN           NaN      NaN
# 3           NaN       NaN           NaN      NaN
# 4           NaN       NaN           NaN      NaN
#
# [5 rows x 34 columns]

# %% [markdown]
# ### Time series analyses
#
# If we want to focus on the incremental drags and drops of an individual trial, as well as the total time it took a participant to complete that trial, we can use the `compute_action_times` function on the relevant rows from the results file.

# %%
# Make a copy of the data for our incremental purposes
incremental = data.copy()

# %%
# Keeping only the rows that are trials
incremental = incremental[incremental['Label'] == 'trials'].copy()

# %%
# Visualizing our trials (note the "Label" column)
incremental.head()
# Out:
#     Results.reception.time MD5.hash.of.participant.s.IP.address  \
# 47              1742304662     abda418378729d84a1a46fe1f54043bc
# 48              1742304662     abda418378729d84a1a46fe1f54043bc
# 49              1742304662     abda418378729d84a1a46fe1f54043bc
# 50              1742304662     abda418378729d84a1a46fe1f54043bc
# 51              1742304662     abda418378729d84a1a46fe1f54043bc
#
#    Controller.name  Order.number.of.item  Inner.element.number   Label  \
# 47  PennController                     6                     0  trials
# 48  PennController                     6                     0  trials
# 49  PennController                     6                     0  trials
# 50  PennController                     6                     0  trials
# 51  PennController                     6                     0  trials
#
#     Latin.Square.Group PennElementType      PennElementName Parameter  ...  \
# 47                 NaN  PennController                    7   _Trial_  ...
# 48                 NaN  PennController                    7  _Header_  ...
# 49                 NaN  PennController                    7  _Header_  ...
# 50                 NaN        DragDrop  experimental-trials      Drag  ...
# 51                 NaN        DragDrop  experimental-trials      Drop  ...
#
#    Sentence4Cond                                Sentence5  Sentence5Cond  \
# 47     ModAware4  Dignitaries condemn the rebellious act.      ModAware4
# 48     ModAware4  Dignitaries condemn the rebellious act.      ModAware4
# 49     ModAware4  Dignitaries condemn the rebellious act.      ModAware4
# 50     ModAware4  Dignitaries condemn the rebellious act.      ModAware4
# 51     ModAware4  Dignitaries condemn the rebellious act.      ModAware4
#
#                                        Sentence6 Sentence6Cond  \
# 47  He had this habit of telling you everything.   NoModAware2
# 48  He had this habit of telling you everything.   NoModAware2
# 49  He had this habit of telling you everything.   NoModAware2
# 50  He had this habit of telling you everything.   NoModAware2
# 51  He had this habit of telling you everything.   NoModAware2
#
#                                            Sentence7 Sentence7Cond  \
# 47  I e-mailed your assistant earlier this morning .   NoModAware4
# 48  I e-mailed your assistant earlier this morning .   NoModAware4
# 49  I e-mailed your assistant earlier this morning .   NoModAware4
# 50  I e-mailed your assistant earlier this morning .   NoModAware4
# 51  I e-mailed your assistant earlier this morning .   NoModAware4
#
#                                            Sentence8 Sentence8Cond  \
# 47  Ben made another happy announcement on March 28.     ModAware2
# 48  Ben made another happy announcement on March 28.     ModAware2
# 49  Ben made another happy announcement on March 28.     ModAware2
# 50  Ben made another happy announcement on March 28.     ModAware2
# 51  Ben made another happy announcement on March 28.     ModAware2
#
#                                           Comments
# 47                                             NaN
# 48                                             NaN
# 49                                             NaN
# 50                             Dropped on (8%2C 2)
# 51  Dopped Dignitaries condemn the rebellious act.
#
# [5 rows x 34 columns]

# %%
# Compute the incremental action times
incremental = compute_action_times(incremental)

# %% [markdown]
# If we visualize `incremental` now, we will now see the following columns:
# - EventIndex (the order of events as trials persisted)
# - TimeSinceLastEvent (how long it took to complete the current event)
# - TotalItemTime (how long the full trial took for this participant)
# - EventTime (the exact time this event occurred)

# %%
# Visualizing the end of the file
incremental.tail()
# Out:
#                            Participant  Item  EventIndex      EventTime  \
# 1250  e8cbee887ff48a5f732382ffa9fac6e1     9          19  1742307856536
# 1251  e8cbee887ff48a5f732382ffa9fac6e1     9          20  1742307857435
# 1252  e8cbee887ff48a5f732382ffa9fac6e1     9          21  1742307858294
# 1253  e8cbee887ff48a5f732382ffa9fac6e1     9          22  1742307858295
# 1254  e8cbee887ff48a5f732382ffa9fac6e1     9          23  1742307858295
#
#       TimeSinceLastEvent  TotalItemTime  Results.reception.time  \
# 1250              1202.0          31798              1742307860
# 1251               899.0          31798              1742307860
# 1252               859.0          31798              1742307860
# 1253                 1.0          31798              1742307860
# 1254                 0.0          31798              1742307860
#
#      Controller.name  Inner.element.number   Label  ...  Sentence4Cond  \
# 1250  PennController                     0  trials  ...   ModVolition2
# 1251  PennController                     0  trials  ...   ModVolition2
# 1252  PennController                     0  trials  ...   ModVolition2
# 1253  PennController                     0  trials  ...   ModVolition2
# 1254  PennController                     0  trials  ...   ModVolition2
#
#                                               Sentence5   Sentence5Cond  \
# 1250  The president demoted the expert from his cabi...  NoModVolition2
# 1251  The president demoted the expert from his cabi...  NoModVolition2
# 1252  The president demoted the expert from his cabi...  NoModVolition2
# 1253  The president demoted the expert from his cabi...  NoModVolition2
# 1254  The president demoted the expert from his cabi...  NoModVolition2
#
#                             Sentence6   Sentence6Cond  \
# 1250  We hauled the horse to Corning.  NoModVolition4
# 1251  We hauled the horse to Corning.  NoModVolition4
# 1252  We hauled the horse to Corning.  NoModVolition4
# 1253  We hauled the horse to Corning.  NoModVolition4
# 1254  We hauled the horse to Corning.  NoModVolition4
#
#                                   Sentence7 Sentence7Cond  \
# 1250  We took our bold cat Mitten camping .  ModVolition2
# 1251  We took our bold cat Mitten camping .  ModVolition2
# 1252  We took our bold cat Mitten camping .  ModVolition2
# 1253  We took our bold cat Mitten camping .  ModVolition2
# 1254  We took our bold cat Mitten camping .  ModVolition2
#
#                          Sentence8  Sentence8Cond  \
# 1250  We trust the caring teacher.   ModVolition4
# 1251  We trust the caring teacher.   ModVolition4
# 1252  We trust the caring teacher.   ModVolition4
# 1253  We trust the caring teacher.   ModVolition4
# 1254  We trust the caring teacher.   ModVolition4
#
#                                                Comments
# 1250                                Dropped on (4%2C 7)
# 1251  Dopped They chased the proud rebels out of the...
# 1252                                                NaN
# 1253                      Value at the end of the trial
# 1254                                                NaN
#
# [5 rows x 37 columns]

# %%
# Saving to CSV
incremental.to_csv('outputs/demo-1-incremental.csv', index=False)

# %% [markdown]
# # Distance Analyses
# Fundamentally, GRIS is used to measure the distance between objects in space. We can see how participants positioned these objects in relation to one another by splitting our data as follows, cleaning the `Final` positions with `clean_string`, building the graphs with `expand_graphs`, and finally calculating the pairwise distances between all objects in a trial with `compute_pairwise_distances`.

# %%
# Keeping the rows which have the "Final" positions of all objects. 
distance = incremental[(incremental['Parameter'] == 'Final') & (incremental['PennElementName'] == 'experimental-trials')].copy()

# %%
distance.head()
# Out:
#                           Participant  Item  EventIndex      EventTime  \
# 49   32ab20bbeccaa48346503c065698e438     6          49  1742304542400
# 93   32ab20bbeccaa48346503c065698e438     7          41  1742304623301
# 135  32ab20bbeccaa48346503c065698e438     8          39  1742304689784
# 167  32ab20bbeccaa48346503c065698e438     9          29  1742304756247
# 191  3cc42984c8fd67719dbad98c057b931f     6          21  1742308199127
#
#      TimeSinceLastEvent  TotalItemTime  Results.reception.time  \
# 49               3998.0         122914              1742304762
# 93               1800.0          80890              1742304762
# 135              2063.0          66475              1742304762
# 167              1824.0          66451              1742304762
# 191              5566.0         117058              1742308418
#
#     Controller.name  Inner.element.number   Label  ...    Sentence4Cond  \
# 49   PennController                     0  trials  ...        ModAware4
# 93   PennController                     0  trials  ...  ModInstigation2
# 135  PennController                     0  trials  ...    ModSentience4
# 167  PennController                     0  trials  ...     ModVolition2
# 191  PennController                     0  trials  ...      NoModAware4
#
#                                              Sentence5      Sentence5Cond  \
# 49              I put my angry foot in the cool water.          ModAware4
# 93   The managers staffed the organization with toa...  NoModInstigation4
# 135               In the end%2C John kept his promise.    NoModSentience2
# 167         They chased the rebels out of the capital.     NoModVolition2
# 191                   I put my foot in the cool water.        NoModAware4
#
#                                              Sentence6    Sentence6Cond  \
# 49                              Jane calls the bluff.       NoModAware2
# 93      I found the agreeable office to be very clean.  ModInstigation4
# 135                                  I saw this place.  NoModSentience4
# 167  You want your dog to admire you as his pack le...   NoModVolition4
# 191                   Jane calls the aggressive bluff.        ModAware2
#
#                                              Sentence7    Sentence7Cond  \
# 49                            Dr. Hart killed our pet.      NoModAware4
# 93   The politician pinched a few energetic nerves ...  ModInstigation2
# 135  Pound for pound%2C mountain lions eat more gen...    ModSentience4
# 167           I encourage you to do this joyful dance.     ModVolition2
# 191                      Dr. Hart killed our kind pet.        ModAware4
#
#                                              Sentence8      Sentence8Cond  \
# 49                         She loves playful giraffes.          ModAware2
# 93   Dr Johnson fixed my neck from a snowboard injury.  NoModInstigation2
# 135                          I enjoyed my lively tour.      ModSentience2
# 167  Sam used his duplicitous company to buy items ...       ModVolition4
# 191                                She loves giraffes.        NoModAware2
#
#     Comments
# 49       NaN
# 93       NaN
# 135      NaN
# 167      NaN
# 191      NaN
#
# [5 rows x 37 columns]

# %%
# What does the output string look like? Ugly!
print(distance['Value'].iloc[0])
# Out:
# Ben made another happy announcement on March 28.:(3%2C 1);I e-mailed your assistant earlier this morning .:(19%2C 1);He had this habit of telling you everything.:(0%2C 5);Dignitaries condemn the rebellious act.:(11%2C 4);I put my angry foot in the cool water.:(18%2C 5);Jane calls the bluff. :(30%2C 1);Dr. Hart killed our pet.:(13%2C 2);She loves playful giraffes.:(30%2C 5)

# %%
# Cleaning the output strings like the one shown in the cell above
distance['final_graphs'] = distance['Value'].apply(clean_string)

# %%
# And showing you the cleaned data:
for item in distance['final_graphs'].iloc[0]:
    print(item)
# Out:
# ('Ben made another happy announcement on March 28.', (3, 1))
# ('I e-mailed your assistant earlier this morning .', (19, 1))
# ('He had this habit of telling you everything.', (0, 5))
# ('Dignitaries condemn the rebellious act.', (11, 4))
# ('I put my angry foot in the cool water.', (18, 5))
# ('Jane calls the bluff. ', (30, 1))
# ('Dr. Hart killed our pet.', (13, 2))
# ('She loves playful giraffes.', (30, 5))

# %% [markdown]
# Now, we'll run `expand_graphs` to prepare our data for all of the pairwise-distance calculations between each object for each trial:

# %%
graphs = expand_graphs(distance)

# %%
graphs.tail()
# Out:
#                            Participant  Item  EventIndex      EventTime  \
# 1252  e8cbee887ff48a5f732382ffa9fac6e1     9          21  1742307858294
# 1252  e8cbee887ff48a5f732382ffa9fac6e1     9          21  1742307858294
# 1252  e8cbee887ff48a5f732382ffa9fac6e1     9          21  1742307858294
# 1252  e8cbee887ff48a5f732382ffa9fac6e1     9          21  1742307858294
# 1252  e8cbee887ff48a5f732382ffa9fac6e1     9          21  1742307858294
#
#       TimeSinceLastEvent  TotalItemTime  Results.reception.time  \
# 1252               859.0          31798              1742307860
# 1252               859.0          31798              1742307860
# 1252               859.0          31798              1742307860
# 1252               859.0          31798              1742307860
# 1252               859.0          31798              1742307860
#
#      Controller.name  Inner.element.number   Label  ...  \
# 1252  PennController                     0  trials  ...
# 1252  PennController                     0  trials  ...
# 1252  PennController                     0  trials  ...
# 1252  PennController                     0  trials  ...
# 1252  PennController                     0  trials  ...
#
#                             Sentence6   Sentence6Cond  \
# 1252  We hauled the horse to Corning.  NoModVolition4
# 1252  We hauled the horse to Corning.  NoModVolition4
# 1252  We hauled the horse to Corning.  NoModVolition4
# 1252  We hauled the horse to Corning.  NoModVolition4
# 1252  We hauled the horse to Corning.  NoModVolition4
#
#                                   Sentence7 Sentence7Cond  \
# 1252  We took our bold cat Mitten camping .  ModVolition2
# 1252  We took our bold cat Mitten camping .  ModVolition2
# 1252  We took our bold cat Mitten camping .  ModVolition2
# 1252  We took our bold cat Mitten camping .  ModVolition2
# 1252  We took our bold cat Mitten camping .  ModVolition2
#
#                          Sentence8  Sentence8Cond Comments  \
# 1252  We trust the caring teacher.   ModVolition4      NaN
# 1252  We trust the caring teacher.   ModVolition4      NaN
# 1252  We trust the caring teacher.   ModVolition4      NaN
# 1252  We trust the caring teacher.   ModVolition4      NaN
# 1252  We trust the caring teacher.   ModVolition4      NaN
#
#                                            final_graphs  \
# 1252  (They chased the proud rebels out of the capit...
# 1252  (The president demoted the expert from his cab...
# 1252         (We hauled the horse to Corning., (27, 4))
# 1252   (We took our bold cat Mitten camping ., (21, 4))
# 1252            (We trust the caring teacher., (26, 6))
#
#                                                  object location
# 1252   They chased the proud rebels out of the capital.   (4, 7)
# 1252  The president demoted the expert from his cabi...   (8, 4)
# 1252                    We hauled the horse to Corning.  (27, 4)
# 1252              We took our bold cat Mitten camping .  (21, 4)
# 1252                       We trust the caring teacher.  (26, 6)
#
# [5 rows x 40 columns]

# %%
# Compute pairwise distances:
pairwise_df = compute_pairwise_distances(
    graphs,
    group_cols=['Participant', 'item'],
    location_col='location',
    object_col='object'
)

# %%
# Check out the "distance" column all the way on the right!
pairwise_df.head()
# Out:
#                         Participant  Item  EventIndex      EventTime  \
# 0  32ab20bbeccaa48346503c065698e438     6          49  1742304542400
# 1  32ab20bbeccaa48346503c065698e438     6          49  1742304542400
# 2  32ab20bbeccaa48346503c065698e438     6          49  1742304542400
# 3  32ab20bbeccaa48346503c065698e438     6          49  1742304542400
# 4  32ab20bbeccaa48346503c065698e438     6          49  1742304542400
#
#    TimeSinceLastEvent  TotalItemTime  Results.reception.time Controller.name  \
# 0              3998.0         122914              1742304762  PennController
# 1              3998.0         122914              1742304762  PennController
# 2              3998.0         122914              1742304762  PennController
# 3              3998.0         122914              1742304762  PennController
# 4              3998.0         122914              1742304762  PennController
#
#    Inner.element.number   Label  ...                 Sentence7 Sentence7Cond  \
# 0                     0  trials  ...  Dr. Hart killed our pet.   NoModAware4
# 1                     0  trials  ...  Dr. Hart killed our pet.   NoModAware4
# 2                     0  trials  ...  Dr. Hart killed our pet.   NoModAware4
# 3                     0  trials  ...  Dr. Hart killed our pet.   NoModAware4
# 4                     0  trials  ...  Dr. Hart killed our pet.   NoModAware4
#
#                      Sentence8 Sentence8Cond Comments  \
# 0  She loves playful giraffes.     ModAware2      NaN
# 1  She loves playful giraffes.     ModAware2      NaN
# 2  She loves playful giraffes.     ModAware2      NaN
# 3  She loves playful giraffes.     ModAware2      NaN
# 4  She loves playful giraffes.     ModAware2      NaN
#
#                                         final_graphs  \
# 0  (Ben made another happy announcement on March ...
# 1  (Ben made another happy announcement on March ...
# 2  (Ben made another happy announcement on March ...
# 3  (Ben made another happy announcement on March ...
# 4  (Ben made another happy announcement on March ...
#
#                                              object  \
# 0  Ben made another happy announcement on March 28.
# 1  Ben made another happy announcement on March 28.
# 2  Ben made another happy announcement on March 28.
# 3  Ben made another happy announcement on March 28.
# 4  Ben made another happy announcement on March 28.
#
#                                            object_2  location_2   distance
# 0  I e-mailed your assistant earlier this morning .     (19, 1)  16.000000
# 1      He had this habit of telling you everything.      (0, 5)   5.000000
# 2           Dignitaries condemn the rebellious act.     (11, 4)   8.544004
# 3            I put my angry foot in the cool water.     (18, 5)  15.524175
# 4                            Jane calls the bluff.      (30, 1)  27.000000
#
# [5 rows x 42 columns]

# %%
# Saving to CSV
pairwise_df.to_csv('outputs/demo-1-distances.csv', index=False)

# %% [markdown]
# Thus concludes the general pipeline for extracting data. Again, we leave it to you to align your stimuli and conditions with the data.
#
# The remaining two sample pipelines will be less detailed, but comments are included to help you follow what's going on.

# %% [markdown]
# ## SAMPLE PIPELINE 2 (GRADIENT):
# #### Typicality data provided by John R. Starr (jrs673@cornell.edu)
#
# I ran a GRIS experiment that studies how people process differences in category typicality. The data provided here are from a demonstration of the task, meaning there are very few trials and items. As in the first pipeline, *we do not line up the experimental items (and their conditions) with the results files to avoid issues with generalization.*
#
# Note that this experiment uses the four-point coordinate system (x_cat, y_cat, x, y).

# %%
# Load in the data
data2 = pd.read_csv('data/demo-2-cleaned.csv')

# %%
# Look at the data
data2.head()
# Out:
#    Results.reception.time MD5.hash.of.participant.s.IP.address  \
# 0              1743628553     8625c054d78abdfb4dce4fa7872cfd0e
# 1              1743628553     8625c054d78abdfb4dce4fa7872cfd0e
# 2              1743628553     8625c054d78abdfb4dce4fa7872cfd0e
# 3              1743628553     8625c054d78abdfb4dce4fa7872cfd0e
# 4              1743628553     8625c054d78abdfb4dce4fa7872cfd0e
#
#   Controller.name  Order.number.of.item  Inner.element.number Label  \
# 0  PennController                     2                     0  demo
# 1  PennController                     2                     0  demo
# 2  PennController                     2                     0  demo
# 3  PennController                     2                     0  demo
# 4  PennController                     2                     0  demo
#
#    Latin.Square.Group PennElementType PennElementName Parameter  \
# 0                 NaN  PennController               2   _Trial_
# 1                 NaN        DragDrop            pt-1      Drag
# 2                 NaN        DragDrop            pt-1      Drop
# 3                 NaN        DragDrop            pt-1      Drag
# 4                 NaN        DragDrop            pt-1      Drop
#
#                  Value      EventTime   item                        Comments
# 0                Start  1743628525864  item2                             NaN
# 1               sprite  1743628527893  item2  Dropped on (1%2C 1%2C 19%2C 5)
# 2  (1%2C 1%2C 19%2C 5)  1743628528570  item2                   Dopped sprite
# 3                pepsi  1743628530951  item2  Dropped on (1%2C 1%2C 11%2C 6)
# 4  (1%2C 1%2C 11%2C 6)  1743628531966  item2                    Dopped pepsi

# %%
# Compute the incremental action times
incremental2 = compute_action_times(data2)

# %%
# Check out what `compute_action_times` gets us:
incremental2.head()
# Out:
#                         Participant  Item  EventIndex      EventTime  \
# 0  8625c054d78abdfb4dce4fa7872cfd0e     1           0  1743628545760
# 1  8625c054d78abdfb4dce4fa7872cfd0e     1           1  1743628547117
# 2  8625c054d78abdfb4dce4fa7872cfd0e     1           2  1743628547404
# 3  8625c054d78abdfb4dce4fa7872cfd0e     1           3  1743628548137
# 4  8625c054d78abdfb4dce4fa7872cfd0e     1           4  1743628548440
#
#    TimeSinceLastEvent  TotalItemTime  Results.reception.time Controller.name  \
# 0                 0.0           6897              1743628553  PennController
# 1              1357.0           6897              1743628553  PennController
# 2               287.0           6897              1743628553  PennController
# 3               733.0           6897              1743628553  PennController
# 4               303.0           6897              1743628553  PennController
#
#    Inner.element.number Label  Latin.Square.Group PennElementType  \
# 0                     0  demo                 NaN  PennController
# 1                     0  demo                 NaN        DragDrop
# 2                     0  demo                 NaN        DragDrop
# 3                     0  demo                 NaN        DragDrop
# 4                     0  demo                 NaN        DragDrop
#
#   PennElementName Parameter                 Value   item  \
# 0               1   _Trial_                 Start  item1
# 1            pt-1      Drag                   cat  item1
# 2            pt-1      Drop   (1%2C 1%2C 18%2C 7)  item1
# 3            pt-1      Drag                 snake  item1
# 4            pt-1      Drop  (1%2C 1%2C 11%2C 11)  item1
#
#                           Comments
# 0                              NaN
# 1   Dropped on (1%2C 1%2C 18%2C 7)
# 2                       Dopped cat
# 3  Dropped on (1%2C 1%2C 11%2C 11)
# 4                     Dopped snake

# %%
# Saving to CSV
incremental2.to_csv('outputs/demo-2-incremental.csv', index=False)

# %%
# Keeping only final positions
distance2 = incremental2[incremental2['Parameter'] == 'Final'].copy()

# %%
# Cleaning the output strings 
distance2['final_graphs'] = distance2['Value'].apply(clean_string)

# %%
# Ensuring our strings look cleaned in the 'final_graphs' column
distance2
# Out:
#                          Participant  Item  EventIndex      EventTime  \
# 11  8625c054d78abdfb4dce4fa7872cfd0e     1          11  1743628552657
# 24  8625c054d78abdfb4dce4fa7872cfd0e     2          11  1743628545757
#
#     TimeSinceLastEvent  TotalItemTime  Results.reception.time Controller.name  \
# 11               851.0           6897              1743628553  PennController
# 24              3050.0          19893              1743628553  PennController
#
#     Inner.element.number Label  Latin.Square.Group PennElementType  \
# 11                     0  demo                 NaN        DragDrop
# 24                     0  demo                 NaN        DragDrop
#
#    PennElementName Parameter  \
# 11            pt-1     Final
# 24            pt-1     Final
#
#                                                 Value   item Comments  \
# 11  cat:(1%2C 1%2C 18%2C 7);dog:(1%2C 1%2C 19%2C 1...  item1      NaN
# 24  sprite:(1%2C 1%2C 19%2C 5);pepsi:(1%2C 1%2C 11...  item2      NaN
#
#                                          final_graphs
# 11  [(cat, (1, 1, 18, 7)), (dog, (1, 1, 19, 13)), ...
# 24  [(sprite, (1, 1, 19, 5)), (pepsi, (1, 1, 11, 6...

# %%
# Expanding our dataframes
graphs2 = expand_graphs(distance2)

# %%
# Compute pairwise distances
pairwise_df2 = compute_pairwise_distances(
    graphs2,
    group_cols=['Participant', 'item'],
    location_col='location',
    object_col='object'
)

# %%
# Check out the "distance" column all the way on the right!
pairwise_df2.head()
# Out:
#                         Participant  Item  EventIndex      EventTime  \
# 0  8625c054d78abdfb4dce4fa7872cfd0e     1          11  1743628552657
# 1  8625c054d78abdfb4dce4fa7872cfd0e     1          11  1743628552657
# 2  8625c054d78abdfb4dce4fa7872cfd0e     1          11  1743628552657
# 3  8625c054d78abdfb4dce4fa7872cfd0e     1          11  1743628552657
# 4  8625c054d78abdfb4dce4fa7872cfd0e     1          11  1743628552657
#
#    TimeSinceLastEvent  TotalItemTime  Results.reception.time Controller.name  \
# 0               851.0           6897              1743628553  PennController
# 1               851.0           6897              1743628553  PennController
# 2               851.0           6897              1743628553  PennController
# 3               851.0           6897              1743628553  PennController
# 4               851.0           6897              1743628553  PennController
#
#    Inner.element.number Label  ...  PennElementName Parameter  \
# 0                     0  demo  ...             pt-1     Final
# 1                     0  demo  ...             pt-1     Final
# 2                     0  demo  ...             pt-1     Final
# 3                     0  demo  ...             pt-1     Final
# 4                     0  demo  ...             pt-1     Final
#
#                                                Value   item Comments  \
# 0  cat:(1%2C 1%2C 18%2C 7);dog:(1%2C 1%2C 19%2C 1...  item1      NaN
# 1  cat:(1%2C 1%2C 18%2C 7);dog:(1%2C 1%2C 19%2C 1...  item1      NaN
# 2  cat:(1%2C 1%2C 18%2C 7);dog:(1%2C 1%2C 19%2C 1...  item1      NaN
# 3  cat:(1%2C 1%2C 18%2C 7);dog:(1%2C 1%2C 19%2C 1...  item1      NaN
# 4  cat:(1%2C 1%2C 18%2C 7);dog:(1%2C 1%2C 19%2C 1...  item1      NaN
#
#             final_graphs object object_2      location_2  distance
# 0   (cat, (1, 1, 18, 7))    cat      dog  (1, 1, 19, 13)  6.082763
# 1   (cat, (1, 1, 18, 7))    cat    snake  (1, 1, 11, 11)  8.062258
# 2   (cat, (1, 1, 18, 7))    cat  hamster  (1, 1, 18, 10)  3.000000
# 3  (dog, (1, 1, 19, 13))    dog    snake  (1, 1, 11, 11)  8.246211
# 4  (dog, (1, 1, 19, 13))    dog  hamster  (1, 1, 18, 10)  3.162278
#
# [5 rows x 22 columns]

# %%
# Saving to CSV
pairwise_df2.to_csv('outputs/demo-2-distances.csv', index=False)

# %% [markdown]
# ## SAMPLE PIPELINE 3 (CATEGORICAL):
# #### Acceptability data provided by John R. Starr (jrs673@cornell.edu)
#
# I ran a GRIS experiment that studies how people process differences in word acceptability. The data provided here are from a demonstration of the task, meaning there are very few trials and items. Again, *we do not line up the experimental items (and their conditions) with the results files to avoid issues with generalization.*
#
# Note that this experiment uses the four-point coordinate system (x_cat, y_cat, x, y).

# %%
# Load in the data
data3 = pd.read_csv('data/demo-3-cleaned.csv')

# %%
# Check out the data
data3.head()
# Out:
#    Results.reception.time MD5.hash.of.participant.s.IP.address  \
# 0              1743629442     8625c054d78abdfb4dce4fa7872cfd0e
# 1              1743629442     8625c054d78abdfb4dce4fa7872cfd0e
# 2              1743629442     8625c054d78abdfb4dce4fa7872cfd0e
# 3              1743629442     8625c054d78abdfb4dce4fa7872cfd0e
# 4              1743629442     8625c054d78abdfb4dce4fa7872cfd0e
#
#   Controller.name  Order.number.of.item  Inner.element.number Label  \
# 0  PennController                     2                     0  demo
# 1  PennController                     2                     0  demo
# 2  PennController                     2                     0  demo
# 3  PennController                     2                     0  demo
# 4  PennController                     2                     0  demo
#
#    Latin.Square.Group PennElementType PennElementName Parameter  \
# 0                 NaN  PennController               2   _Trial_
# 1                 NaN        DragDrop            pt-1      Drag
# 2                 NaN        DragDrop            pt-1      Drop
# 3                 NaN        DragDrop            pt-1      Drag
# 4                 NaN        DragDrop            pt-1      Drop
#
#                 Value      EventTime   item                       Comments
# 0               Start  1743629417343  item2                            NaN
# 1              sprite  1743629418701  item2  Dropped on (3%2C 0%2C 0%2C 0)
# 2  (3%2C 0%2C 0%2C 0)  1743629419633  item2                  Dopped sprite
# 3               pepsi  1743629421361  item2  Dropped on (5%2C 0%2C 1%2C 1)
# 4  (5%2C 0%2C 1%2C 1)  1743629422244  item2                   Dopped pepsi

# %%
# Compute the incremental action times
incremental3 = compute_action_times(data3)

# %%
# Saving to CSV
incremental3.to_csv('outputs/demo-3-incremental.csv', index=False)

# %%
# Keeping the final graph positions
distance3 = incremental3[incremental3['Parameter'] == 'Final'].copy()

# %%
# Cleaning the output strings 
distance3['final_graphs'] = distance3['Value'].apply(clean_string)

# %%
# Ensuring our graphs are cleaned
distance3
# Out:
#                          Participant  Item  EventIndex      EventTime  \
# 10  8625c054d78abdfb4dce4fa7872cfd0e     1          10  1743629441512
# 24  8625c054d78abdfb4dce4fa7872cfd0e     2          12  1743629433030
#
#     TimeSinceLastEvent  TotalItemTime  Results.reception.time Controller.name  \
# 10               852.0           8479              1743629442  PennController
# 24              1571.0          15688              1743629442  PennController
#
#     Inner.element.number Label  Latin.Square.Group PennElementType  \
# 10                     0  demo                 NaN        DragDrop
# 24                     0  demo                 NaN        DragDrop
#
#    PennElementName Parameter  \
# 10            pt-1     Final
# 24            pt-1     Final
#
#                                                 Value   item Comments  \
# 10  cat:(5%2C 0%2C 0%2C 0);dog:(2%2C 0%2C 1%2C 1);...  item1      NaN
# 24  sprite:(3%2C 0%2C 0%2C 0);pepsi:(5%2C 0%2C 1%2...  item2      NaN
#
#                                          final_graphs
# 10  [(cat, (5, 0, 0, 0)), (dog, (2, 0, 1, 1)), (sn...
# 24  [(sprite, (3, 0, 0, 0)), (pepsi, (5, 0, 1, 1))...

# %%
# Expanding the screens
graphs3 = expand_graphs(distance3)

# %%
# Compute pairwise distances
pairwise_df3 = compute_pairwise_distances(
    graphs3,
    group_cols=['Participant', 'item'],
    location_col='location',
    object_col='object',
    categorical=True        # Note: Categorical = True will calculate
                            # differences in the first two coordinates
                            # rather than the last two coordinates.
)

# %%
# Check out the "distance" column all the way on the right!
pairwise_df3.head()
# Out:
#                         Participant  Item  EventIndex      EventTime  \
# 0  8625c054d78abdfb4dce4fa7872cfd0e     1          10  1743629441512
# 1  8625c054d78abdfb4dce4fa7872cfd0e     1          10  1743629441512
# 2  8625c054d78abdfb4dce4fa7872cfd0e     1          10  1743629441512
# 3  8625c054d78abdfb4dce4fa7872cfd0e     1          10  1743629441512
# 4  8625c054d78abdfb4dce4fa7872cfd0e     1          10  1743629441512
#
#    TimeSinceLastEvent  TotalItemTime  Results.reception.time Controller.name  \
# 0               852.0           8479              1743629442  PennController
# 1               852.0           8479              1743629442  PennController
# 2               852.0           8479              1743629442  PennController
# 3               852.0           8479              1743629442  PennController
# 4               852.0           8479              1743629442  PennController
#
#    Inner.element.number Label  ...  PennElementName Parameter  \
# 0                     0  demo  ...             pt-1     Final
# 1                     0  demo  ...             pt-1     Final
# 2                     0  demo  ...             pt-1     Final
# 3                     0  demo  ...             pt-1     Final
# 4                     0  demo  ...             pt-1     Final
#
#                                                Value   item Comments  \
# 0  cat:(5%2C 0%2C 0%2C 0);dog:(2%2C 0%2C 1%2C 1);...  item1      NaN
# 1  cat:(5%2C 0%2C 0%2C 0);dog:(2%2C 0%2C 1%2C 1);...  item1      NaN
# 2  cat:(5%2C 0%2C 0%2C 0);dog:(2%2C 0%2C 1%2C 1);...  item1      NaN
# 3  cat:(5%2C 0%2C 0%2C 0);dog:(2%2C 0%2C 1%2C 1);...  item1      NaN
# 4  cat:(5%2C 0%2C 0%2C 0);dog:(2%2C 0%2C 1%2C 1);...  item1      NaN
#
#           final_graphs object object_2    location_2 distance
# 0  (cat, (5, 0, 0, 0))    cat      dog  (2, 0, 1, 1)      3.0
# 1  (cat, (5, 0, 0, 0))    cat    snake  (3, 0, 0, 1)      2.0
# 2  (cat, (5, 0, 0, 0))    cat  hamster  (1, 0, 0, 1)      4.0
# 3  (dog, (2, 0, 1, 1))    dog    snake  (3, 0, 0, 1)      1.0
# 4  (dog, (2, 0, 1, 1))    dog  hamster  (1, 0, 0, 1)      1.0
#
# [5 rows x 22 columns]

# %%
# Saving to CSV
pairwise_df3.to_csv('outputs/demo-3-distances.csv', index=False)
